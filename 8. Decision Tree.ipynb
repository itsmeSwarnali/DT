# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot #visualization
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor # Import Decision Tree Classifier

# %%
df = pd.read_csv("F:\Machine Learning\Datasets\Latest Covid-19 India Status.csv")
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar         7566       6        7431
# 1                             Andhra Pradesh      2014116   14693     1985566
# 2                          Arunachal Pradesh        53031     863       51908
# 3                                      Assam       589426    6901      576865
# 4                                      Bihar       725708     100      715955
# 5                                 Chandigarh        65105      40       64252
# 6                               Chhattisgarh      1004451     412      990484
# 7   Dadra and Nagar Haveli and Daman and Diu        10663       4       10655
# 8                                      Delhi      1437764     349     1412333
# 9                                        Goa       173955     877      169877
# 10                                   Gujarat       825422     150      815191
# ...

# %%
df.isnull().sum()
# Out:
# State/UTs              0
# Total Cases            0
# Active                 0
# Discharged             0
# Deaths                 0
# Active Ratio (%)       0
# Discharge Ratio (%)    0
# Death Ratio (%)        0
# dtype: int64

# %% [markdown]
# **OneHot Encoding**

# %%
#dummy_var_in = pd.get_dummies(df['State/UTs'],drop_first=True)

# %%
#dummy_var_in.head()

# %%
#new_df = df.drop("State/UTs", axis = 1)

# %%
#new_df

# %%
#df = pd.concat([new_df,dummy_var_in],axis=1) ##Concating
#df.head()

# %%
label = LabelEncoder()

# %%
df['State/UTs'] = label.fit_transform(df['State/UTs'])
df
# Out:
#     State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio (%)  \
# 0           0         7566       6        7431     129              0.08
# 1           1      2014116   14693     1985566   13857              0.73
# 2           2        53031     863       51908     260              1.63
# 3           3       589426    6901      576865    5660              1.17
# 4           4       725708     100      715955    9653              0.01
# 5           5        65105      40       64252     813              0.06
# 6           6      1004451     412      990484   13555              0.04
# 7           7        10663       4       10655       4              0.04
# 8           8      1437764     349     1412333   25082              0.02
# 9           9       173955     877      169877    3201              0.50
# 10         10       825422     150      815191   10081              0.02
# 11         11       770486     634      760175    9677              0.08
# ...

# %%
x = df.drop("Deaths", axis=1)

# %%
y = df["Deaths"]

# %%
x.head()
# Out:
#    State/UTs  Total Cases  Active  Discharged  Active Ratio (%)  \
# 0          0         7566       6        7431              0.08
# 1          1      2014116   14693     1985566              0.73
# 2          2        53031     863       51908              1.63
# 3          3       589426    6901      576865              1.17
# 4          4       725708     100      715955              0.01
#
#    Discharge Ratio (%)  Death Ratio (%)
# 0                98.22             1.70
# 1                98.58             0.69
# 2                97.88             0.49
# 3                97.87             0.96
# 4                98.66             1.33

# %%
x.shape
# Out:
# (36, 7)

# %%
y.head()
# Out:
# 0      129
# 1    13857
# 2      260
# 3     5660
# 4     9653
# Name: Deaths, dtype: int64

# %%
y.shape
# Out:
# (36,)

# %% [markdown]
# **Standardization**

# %%
#std = StandardScaler()

# %%
#new_x = std.fit_transform(x)
#x = pd.DataFrame(new_x, columns = x.columns)

# %%
x.head()
# Out:
#    State/UTs  Total Cases  Active  Discharged  Active Ratio (%)  \
# 0          0         7566       6        7431              0.08
# 1          1      2014116   14693     1985566              0.73
# 2          2        53031     863       51908              1.63
# 3          3       589426    6901      576865              1.17
# 4          4       725708     100      715955              0.01
#
#    Discharge Ratio (%)  Death Ratio (%)
# 0                98.22             1.70
# 1                98.58             0.69
# 2                97.88             0.49
# 3                97.87             0.96
# 4                98.66             1.33

# %% [markdown]
# **Train Test Split**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size=.30, random_state=1)

# %%
X_train.shape
# Out:
# (25, 7)

# %%
Y_train.shape
# Out:
# (25,)

# %%
X_test.shape
# Out:
# (11, 7)

# %%
dt = DecisionTreeRegressor()

# %%
dt.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor()

# %%
#Predicting
pred=dt.predict(X_test)
pred
# Out:
# array([37318.,  5132., 10081.,  3873.,  9653.,    51.,  1311.,   260.,
#           51.,   800.,  5132.])

# %%
Y_test
# Out:
# 30    34921
# 34     7387
# 28     8954
# 3      5660
# 19    10516
# 17      207
# 21     1782
# 23      217
# 29      370
# 26     1812
# 27    16431
# Name: Deaths, dtype: int64

# %%
print(Y_test.mean())
y_test_perc = Y_test.mean()
# Out:
# 8023.363636363636

# %%
dt.score(X_test, Y_test)
# Out:
# 0.863823713996864

# %%
from sklearn import tree
plot.figure(figsize=(50,50))
tree.plot_tree(dt)
# Out:
# [Text(1952.9999999999998, 2582.1, 'X[3] <= 5044902.0\nmse = 722547852.65\nsamples = 25\nvalue = 14030.52'),
#  Text(1873.2857142857142, 2310.3, 'X[3] <= 1202784.0\nmse = 92993862.354\nsamples = 24\nvalue = 8893.75'),
#  Text(1355.142857142857, 2038.5, 'X[1] <= 691881.0\nmse = 17195513.472\nsamples = 18\nvalue = 4174.167'),
#  Text(797.1428571428571, 1766.6999999999998, 'X[3] <= 125560.5\nmse = 3261672.249\nsamples = 13\nvalue = 1861.538'),
#  Text(478.2857142857142, 1494.8999999999999, 'X[3] <= 58080.0\nmse = 187866.25\nsamples = 8\nvalue = 498.5'),
#  Text(318.85714285714283, 1223.1, 'X[6] <= 1.88\nmse = 48967.76\nsamples = 5\nvalue = 212.8'),
#  Text(239.1428571428571, 951.3, 'X[3] <= 31281.5\nmse = 9393.5\nsamples = 4\nvalue = 111.0'),
#  Text(159.42857142857142, 679.5, 'X[0] <= 3.5\nmse = 2657.556\nsamples = 3\nvalue = 61.333'),
#  Text(79.71428571428571, 407.6999999999998, 'mse = 0.0\nsamples = 1\nvalue = 129.0'),
# ...
